# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# %%
df = pd.read_csv("/content/student-mat (1).csv", sep=";")

# %%
le = LabelEncoder()

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col])

# %%
X = df.drop("G3", axis=1)
Y = df["G3"]

# %%
print(df.dtypes)
# Out:
# school        int64
# sex           int64
# age           int64
# address       int64
# famsize       int64
# Pstatus       int64
# Medu          int64
# Fedu          int64
# Mjob          int64
# Fjob          int64
# reason        int64
# guardian      int64
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup     int64
# famsup        int64
# paid          int64
# activities    int64
# nursery       int64
# higher        int64
# internet      int64
# romantic      int64
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
print(df.isnull().sum())
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df = df.dropna()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# Build ANN Model
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

# Compile Model
model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

# Model Summary
model.summary()

# Train Model
history = model.fit(
    X_train,
    Y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)

# Evaluate Model
loss, mae = model.evaluate(X_test, Y_test)

print("\nTest MAE:", mae)

# Predict First 5 Students
predictions = model.predict(X_test[:5])

for i in range(5):
    print(f"Actual Grade: {Y_test.iloc[i]}")
    print(f"Predicted Grade: {predictions[i][0]:.2f}")
    print("-" * 30)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,225 (16.50 KB)
#  Trainable params: 4,225 (16.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 131.7167 - mae: 10.5041 - val_loss: 124.3936 - val_mae: 10.3791
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 120.6664 - mae: 10.0288 - val_loss: 113.3817 - val_mae: 9.8872
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 110.2320 - mae: 9.5894 - val_loss: 102.5642 - val_mae: 9.3916
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 99.7863 - mae: 9.1473 - val_loss: 91.4343 - val_mae: 8.8644
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 88.4944 - mae: 8.6224 - val_loss: 79.6679 - val_mae: 8.2637
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 76.1547 - mae: 8.0160 - val_loss: 67.1215 - val_mae: 7.5564
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 63.3541 - mae: 7.3015 - val_loss: 53.9332 - val_mae: 6.7179
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 49.7692 - mae: 6.4335 - val_loss: 41.2775 - val_mae: 5.8125
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 37.4516 - mae: 5.5069 - val_loss: 29.7938 - val_mae: 4.8231
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 26.5195 - mae: 4.5352 - val_loss: 20.9711 - val_mae: 3.9053
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.4780 - mae: 3.6927 - val_loss: 15.2217 - val_mae: 3.2257
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.4983 - mae: 3.0301 - val_loss: 12.1974 - val_mae: 2.7073
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 11.0200 - mae: 2.6088 - val_loss: 10.7307 - val_mae: 2.4260
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.6100 - mae: 2.3784 - val_loss: 9.8460 - val_mae: 2.2847
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5791 - mae: 2.2213 - val_loss: 9.0823 - val_mae: 2.1913
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6537 - mae: 2.0800 - val_loss: 8.4995 - val_mae: 2.1327
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9429 - mae: 1.9764 - val_loss: 8.0448 - val_mae: 2.0967
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3785 - mae: 1.8849 - val_loss: 7.6789 - val_mae: 2.0706
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.9494 - mae: 1.8120 - val_loss: 7.4163 - val_mae: 2.0385
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5856 - mae: 1.7512 - val_loss: 7.2626 - val_mae: 2.0137
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2913 - mae: 1.6974 - val_loss: 7.0444 - val_mae: 1.9828
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0311 - mae: 1.6519 - val_loss: 6.8997 - val_mae: 1.9497
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8279 - mae: 1.6122 - val_loss: 6.7205 - val_mae: 1.9249
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6147 - mae: 1.5773 - val_loss: 6.6068 - val_mae: 1.9034
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4300 - mae: 1.5452 - val_loss: 6.5362 - val_mae: 1.9013
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2657 - mae: 1.5185 - val_loss: 6.4693 - val_mae: 1.9019
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1119 - mae: 1.4900 - val_loss: 6.3617 - val_mae: 1.8910
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9614 - mae: 1.4621 - val_loss: 6.2724 - val_mae: 1.8858
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8250 - mae: 1.4365 - val_loss: 6.2279 - val_mae: 1.8835
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6985 - mae: 1.4116 - val_loss: 6.1695 - val_mae: 1.8733
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5862 - mae: 1.3912 - val_loss: 6.1080 - val_mae: 1.8677
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4597 - mae: 1.3689 - val_loss: 6.0708 - val_mae: 1.8572
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3543 - mae: 1.3473 - val_loss: 6.0338 - val_mae: 1.8578
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2451 - mae: 1.3243 - val_loss: 5.9743 - val_mae: 1.8448
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1489 - mae: 1.3058 - val_loss: 5.9397 - val_mae: 1.8423
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0396 - mae: 1.2859 - val_loss: 5.9099 - val_mae: 1.8360
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9464 - mae: 1.2659 - val_loss: 5.8757 - val_mae: 1.8328
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8529 - mae: 1.2448 - val_loss: 5.8423 - val_mae: 1.8276
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7693 - mae: 1.2264 - val_loss: 5.8079 - val_mae: 1.8234
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6765 - mae: 1.2064 - val_loss: 5.7621 - val_mae: 1.8169
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5948 - mae: 1.1890 - val_loss: 5.7468 - val_mae: 1.8128
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5101 - mae: 1.1709 - val_loss: 5.7630 - val_mae: 1.8157
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4301 - mae: 1.1525 - val_loss: 5.7147 - val_mae: 1.8081
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3537 - mae: 1.1321 - val_loss: 5.7058 - val_mae: 1.8082
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2831 - mae: 1.1146 - val_loss: 5.6802 - val_mae: 1.7980
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2138 - mae: 1.0988 - val_loss: 5.6614 - val_mae: 1.7991
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1365 - mae: 1.0812 - val_loss: 5.6502 - val_mae: 1.7937
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0668 - mae: 1.0639 - val_loss: 5.6182 - val_mae: 1.7894
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0116 - mae: 1.0499 - val_loss: 5.5867 - val_mae: 1.7793
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9402 - mae: 1.0326 - val_loss: 5.5133 - val_mae: 1.7741
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.2462 - mae: 2.0871
#
# Test MAE: 2.0870742797851562
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Actual Grade: 10
# Predicted Grade: 5.10
# ------------------------------
# Actual Grade: 12
# Predicted Grade: 13.79
# ------------------------------
# Actual Grade: 5
# Predicted Grade: 2.60
# ------------------------------
# Actual Grade: 10
# Predicted Grade: 8.59
# ------------------------------
# Actual Grade: 9
# Predicted Grade: 13.42
# ------------------------------
